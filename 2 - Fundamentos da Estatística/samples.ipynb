# %%
#Geração de dados aleatórios

# %%
import random
import numpy as np

# %%
x = random.random()
print(x)
# Out:
# 0.2783265343799519

# %%
random.seed(777)

# %%
X = []
for i in range (100):
  X.append(random.random())

# %%
len(X)
# Out:
# 100

# %%
X.head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-cb32f7eb5f0b> in <module>()
# ----> 1 X.head(10)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
nomes = ['Lucas', 'Marcos', 'Thiago', 'Robert', 'Bianca', 'Erika']

# %%
nomes
# Out:
# ['Lucas', 'Marcos', 'Thiago', 'Robert', 'Bianca', 'Erika']

# %%
random.choice(nomes)
# Out:
# 'Thiago'

# %%
random.shuffle(nomes)

# %%
nomes
# Out:
# ['Bianca', 'Erika', 'Thiago', 'Marcos', 'Robert', 'Lucas']

# %%
random.sample(nomes, 3)
# Out:
# ['Lucas', 'Bianca', 'Thiago']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-9b047dab57dd> in <module>()
# ----> 1 np.random.randn(nomes)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randn()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.standard_normal()
#
# _common.pyx in numpy.random._common.cont()
#
# TypeError: 'list' object cannot be interpreted as an integer
