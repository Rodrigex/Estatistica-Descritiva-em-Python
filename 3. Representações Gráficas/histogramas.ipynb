# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.randn(1000)

# %%
plt.hist(x, bins = 15, color -)
plt.xlabel('Eixo X')
plt.ylabel('Frequências')
# Out:
# Text(0, 0.5, 'Frequências')
