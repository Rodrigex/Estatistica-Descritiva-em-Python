# %%
#Lista no Python

# %%
lista = []

# %%
type(lista)
# Out:
# list

# %%
carros = ['Clio', 'Gol', 'Celta']

# %%
carros
# Out:
# ['Clio', 'Gol', 'Celta']

# %%
carros[0]
# Out:
# 'Clio'

# %%
carros[-1]
# Out:
# 'Celta'

# %%
carros.append('Fox')

# %%
carros
# Out:
# ['Clio', 'Gol', 'Celta', 'Fox']

# %%
carros.remove('Gol')

# %%
carros
# Out:
# ['Clio', 'Celta', 'Fox']

# %%
carros.pop(1)
# Out:
# 'Celta'

# %%
carros
# Out:
# ['Clio', 'Fox']

# %%
carros.append('Fox')

# %%
carros
# Out:
# ['Clio', 'Fox', ['Fox', 'Celta', 'Meriva'], 'Fox']

# %%
len(carros)
# Out:
# 3

# %%
carros[0:3]
# Out:
# ['Clio', 'Fox', ['Fox', 'Celta', 'Meriva']]

# %%
carros[:3]
# Out:
# ['Clio', 'Fox', ['Fox', 'Celta', 'Meriva']]

# %%
carros.index('Clio')
# Out:
# 0
