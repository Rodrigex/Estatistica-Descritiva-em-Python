# %%
#Declarações Condicionais

# %%
x = 0

# %%
if  x > 0:
  print('Verdadeiro')
else:
  print('Falso')
# Out:
# Verdadeiro

# %%
if  x > 0:
  print('Verdadeiro')
elif x == 0:
  print('Igual a zero')
elif x < 0:
  print('Menor que zero')
else:
  print('Indefinido')
# Out:
# Igual a zero
