# %%
type(2)
# Out:
# int

# %%
type(2.0)
# Out:
# float

# %%
type('python')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
isinstance(2.0, int)
# Out:
# False

# %%
isinstance(2, int)
# Out:
# True

# %%
isinstance(4.0, (int, float, bool))
# Out:
# True

# %%
 float(2)
# Out:
# 2.0

# %%
int(7.9)
# Out:
# 7

# %%
str(7.5)
# Out:
# '7.5'

# %%
bool(5)
# Out:
# True

# %%
bool(0)
# Out:
# False
