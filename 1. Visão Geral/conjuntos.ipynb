# %%
#COnjuntos

# %%
lista = [1,2,3,5]

# %%
c = set(lista)

# %%
c.add(55)

# %%
c
# Out:
# {1, 2, 3, 5, 55}

# %%
c1 = {1,2,3,4}

# %%
c2 = set((1,2,88))

# %%
c2
# Out:
# {1, 2, 88}

# %%
c1.intersection(c2)
# Out:
# {1, 2}

# %%
c1.union(c2)
# Out:
# {1, 2, 3, 4, 88}

# %%
8 in c1
# Out:
# False

# %%
2 in c1
# Out:
# True
