# %%
5 + 3
# Out:
# 8

# %%
9 -5
# Out:
# 4

# %%
7 * 8
# Out:
# 56

# %%
2 ** 5 #potência
# Out:
# 32

# %%
4 / 5
# Out:
# 0.8

# %%
7 % 2 #calcular o resto da divisão
# Out:
# 1

# %%
10 / 4
# Out:
# 2.5

# %%
10 // 4
# Out:
# 2
