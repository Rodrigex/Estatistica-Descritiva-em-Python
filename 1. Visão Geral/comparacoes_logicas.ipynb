# %%
7 > 2
# Out:
# True

# %%
5 >= 2
# Out:
# True

# %%
6 != 8
# Out:
# True

# %%
5 != 5.0
# Out:
# False

# %%
9 > 10 and 3 < 9
# Out:
# False

# %%
not false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-031d0ffe67c2> in <module>()
# ----> 1 not false
#
# NameError: name 'false' is not defined

# %%
not 5! = 5
