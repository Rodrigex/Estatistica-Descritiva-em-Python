# %%
import random

# %%
T = 8000 # Tentativas de Sorteios

# %%
I = 0

for i in range(T):
  x = random.random()
  y = random.random()
  if(((x*x) + (y*y)) < 1):
    I = I + 1

# %%
I
# Out:
# 6266

# %%
Pi = 4*I/T
Pi
# Out:
# 3.133
