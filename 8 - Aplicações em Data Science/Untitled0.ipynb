# %%
from google.colab import files
import io


import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Estatistica descritiva com Python/8 - Aplicações em Data Science/PETR4.SA.csv')

# %%
df.shape
# Out:
# (20, 7)

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2019-04-29  27.549999  27.620001  27.340000  27.370001  27.266680  27689800
# 1  2019-04-30  27.520000  27.660000  26.980000  27.110001  27.007660  39570700
# 2  2019-05-02  26.799999  26.820000  26.520000  26.730000  26.629093  37820300
# 3  2019-05-03  26.900000  27.070000  26.850000  26.850000  26.748642  33334800
# 4  2019-05-06  26.389999  26.770000  26.360001  26.770000  26.668943  31715900

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#             Open       High        Low      Close  Adj Close        Volume
# count  20.000000  20.000000  20.000000  20.000000  20.000000  2.000000e+01
# mean   26.305000  26.567000  26.016000  26.322500  26.242885  4.267958e+07
# std     0.729329   0.636000   0.731037   0.690986   0.684796  1.468141e+07
# min    24.680000  25.420000  24.469999  24.680000  24.586834  5.958500e+06
# 25%    25.867500  26.182500  25.625000  25.895000  25.830557  3.384908e+07
# 50%    26.304999  26.479999  26.040000  26.364999  26.335000  4.135840e+07
# 75%    26.817500  26.957500  26.445000  26.785000  26.683886  5.025915e+07
# max    27.549999  27.660000  27.340000  27.370001  27.266680  7.178030e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       20 non-null     object
#  1   Open       20 non-null     float64
#  2   High       20 non-null     float64
#  3   Low        20 non-null     float64
#  4   Close      20 non-null     float64
#  5   Adj Close  20 non-null     float64
#  6   Volume     20 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
# Coeficiente de Variação

CV = df.std()/df.mean()*100
CV
# Out:
# Open          2.772588
# High          2.393947
# Low           2.809952
# Close         2.625079
# Adj Close     2.609452
# Volume       34.399153
# dtype: float64

# %%
#Histogramas

df['Close'].hist()
plt.xlabel('Preço', size=14)
plt.ylabel('Frequência', size=14)

#Média, mediana

plt.plot(df['Close'].median(),0,'*r')
plt.plot(df['Close'].mean(),0,'og')
plt.show()

# %%
df.iloc[:,0:6].boxplot()
plt.show()

# %%
sns.boxplot(data = df.iloc[:, 0:6])
plt.show()

# %%
# Gráfico de linhas

df.iloc[:, 0:6].plot()
plt.show()
