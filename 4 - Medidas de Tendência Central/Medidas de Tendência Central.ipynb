# %%
#São chamadas MTC por indicarem um ponto do qual se concentram os dados.

# %%
#Medidas descritivas para resumir dados.

#Se calculadas a partir de dados populacionais temos parâmetros

#Se calculadas a partir de dados amostrais temos ESTIMADORES ou ESTATÍTICAS

# %%
#MÉDIA

#MODA

#MEDIANA

#PERCENTIS
